# %% [markdown]
# Loading Data in Pandas DataFrame
#
# Reading CSV file using pd.read_csv and loading data into data frame. Import pandas as using pd for the shorthand.

# %%
#Importing pandas library
import pandas as pd

#Loading data into a DataFrame
data_frame=pd.read_csv('/content/Mall_Customers.csv')

# %% [markdown]
# Printing rows of the Data
#
# By default, data_frame.head() displays the first five rows and data_frame.tail() displays last five rows. If we want to get first ‘n’ number of rows then we use, data_frame.head(n) similar is the syntax to print the last n rows of the data frame.

# %%
#displaying first five rows
display(data_frame.head())
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0

# %%
#displaying last five rows
display(data_frame.tail())
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0

# %% [markdown]
# Printing the column names of the DataFrame –

# %%
# Program to print all the column name of the dataframe
print(list(data_frame.columns))
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %% [markdown]
# Summary of Data Frame
#
# The functions info() prints the summary of a DataFrame that includes the data type of each column, RangeIndex (number of rows), columns, non-null values, and memory usage.

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     197 non-null    float64
#  3   Annual Income (k$)      198 non-null    float64
#  4   Spending Score (1-100)  199 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 7.9+ KB

# %%
data_frame.shape
# Out:
# (200, 5)

# %% [markdown]
# Descriptive Statistical Measures of a DataFrame
#
# The describe() function outputs descriptive statistics which include those that summarize the central tendency, dispersion, and shape of a dataset’s distribution, excluding NaN values. For numeric data, the result’s index will include count, mean, std, min, and max as well as lower, 50, and upper percentiles. For object data (e.g. strings), the result’s index will include count, unique, top, and freq.

# %%
data_frame.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  197.000000          198.000000              199.000000
# mean   100.500000   39.000000           61.005051               50.256281
# std     57.879185   14.002915           26.017857               25.876350
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   29.000000           42.250000               34.500000
# 50%    100.500000   36.000000           62.000000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# Missing Data Handing
#
# a) Find missing values in the dataset:
#
# The isnull( ) detects the missing values and returns a boolean object indicating if the values are NA. The values which are none or empty get mapped to true values and not null values get mapped to false values.

# %%
data_frame.isnull( )
# Out:
#      CustomerID  Gender    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False   False  False               False                    True
# 1         False   False   True               False                   False
# 2         False   False  False               False                   False
# 3         False   False  False                True                   False
# 4         False   False   True                True                   False
# ..          ...     ...    ...                 ...                     ...
# 195       False   False  False               False                   False
# 196       False   False  False               False                   False
# 197       False   False  False               False                   False
# 198       False   False  False               False                   False
# 199       False   False  False               False                   False
#
# [200 rows x 5 columns]

# %% [markdown]
# b) Find the number of missing values in the dataset:
#
# To find out the number of missing values in the dataset, use data_frame.isnull( ).sum( ). In the below example, the dataset doesn’t contain any null values. Hence, each column’s output is 0.

# %%
data_frame.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       3
# Annual Income (k$)        2
# Spending Score (1-100)    1
# dtype: int64

# %%
#To find the percentage of missing data per variable
data_frame.isna().sum()/len(data_frame)*100
# Out:
# CustomerID                0.0
# Gender                    0.0
# Age                       1.5
# Annual Income (k$)        1.0
# Spending Score (1-100)    0.5
# dtype: float64

# %% [markdown]
# c) Removing missing values:
#
# The data_frame.dropna( ) function removes columns or rows which contains atleast one missing values.
#
# By default, data_frame.dropna( ) drops the rows where at least one element is missing.This is also the same as
# data_frame.dropna(axis = 0)
# data_frame.dropna(axis = 1) drops the columns where at least one element is missing.

# %%
df_missing_drop = data_frame.dropna()

# %%
df_missing_drop
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 2             3  Female  20.0                16.0                     6.0
# 5             6  Female  22.0                17.0                    76.0
# 7             8  Female  23.0                18.0                    94.0
# 8             9    Male  64.0                19.0                     3.0
# 9            10  Female  30.0                19.0                    72.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [195 rows x 5 columns]

# %%
df_variable_drop=data_frame.dropna(axis = 1)
df_variable_drop
# Out:
#      CustomerID  Gender
# 0             1    Male
# 1             2    Male
# 2             3  Female
# 3             4  Female
# 4             5  Female
# ..          ...     ...
# 195         196  Female
# 196         197  Female
# 197         198    Male
# 198         199    Male
# 199         200    Male
#
# [200 rows x 2 columns]

# %% [markdown]
# d) Fill in missing values:
#
# We can fill null values using data_frame.fillna( ) function.
#
# data_frame = data_frame.fillna(value)

# %%
df_filled_missing = data_frame.fillna(4)
df_filled_missing
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                     4.0
# 1             2    Male   4.0                15.0                    81.0
# 2             3  Female  20.0                16.0                     6.0
# 3             4  Female  23.0                 4.0                    77.0
# 4             5  Female   4.0                 4.0                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %% [markdown]
# But by using the above format all the null values will get filled with the same values. To fill different values in the different columns we can use.
# data_frame[col] = data_frame[col].fillna(value)

# %%
#Loading data into a DataFrame
data_frame=pd.read_csv('/content/Mall_Customers.csv')
df_AnnualIncome_filled = data_frame["Annual Income (k$)"].fillna(18)
df_AnnualIncome_filled
# Out:
# 0       15.0
# 1       15.0
# 2       16.0
# 3       18.0
# 4       18.0
#        ...
# 195    120.0
# 196    126.0
# 197    126.0
# 198    137.0
# 199    137.0
# Name: Annual Income (k$), Length: 200, dtype: float64

# %% [markdown]
# ## **Row and column manipulations**
# a) Removing rows:
#
# By using the drop(index) function we can drop the row at a particular index. If we want to replace the data_frame with the row removed then add inplace = True in the drop function.

# %%
#Show the data before dropping the 4th raw
data_frame.head()
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0

# %%
# Show the number of raws and variables before dropping record No.4
data_frame.shape
# Out:
# (200, 5)

# %%
#Removing 4th indexed value from the dataframe
data_frame.drop(4).head()
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 5           6  Female  22.0                17.0                    76.0

# %%
#SHowing the number of raws and variables after droppinf record No.4
data_frame.drop(4).shape
# Out:
# (199, 5)

# %% [markdown]
# This function can also be used to remove the columns of a data frame by adding the attribute axis =1 and providing the list of columns we would like to remove.
# data_frame = data_frame.drop('column_name', axis=1)

# %%
data_frame.drop('Age',axis=1).head()
# Out:
#    CustomerID  Gender  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male                15.0                     NaN
# 1           2    Male                15.0                    81.0
# 2           3  Female                16.0                     6.0
# 3           4  Female                 NaN                    77.0
# 4           5  Female                 NaN                    40.0

# %% [markdown]
# b) Renaming rows:
#
# The rename function can be used to rename the rows or columns of the data frame.

# %%
data_frame.rename({0:"First",1:"Second"})
# Out:
#         CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# First            1    Male  19.0                15.0                     NaN
# Second           2    Male   NaN                15.0                    81.0
# 2                3  Female  20.0                16.0                     6.0
# 3                4  Female  23.0                 NaN                    77.0
# 4                5  Female   NaN                 NaN                    40.0
# ...            ...     ...   ...                 ...                     ...
# 195            196  Female  35.0               120.0                    79.0
# 196            197  Female  45.0               126.0                    28.0
# 197            198    Male  32.0               126.0                    74.0
# 198            199    Male  32.0               137.0                    18.0
# 199            200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
#To rename the culumns we list the original names of the columns to change and then use attribute axis=1
data_frame.rename({'CustomerID':"ID",'Gender':"Sex", 'Annual Income (k$)':"Salary"}, axis=1)
# Out:
#       ID     Sex   Age  Salary  Spending Score (1-100)
# 0      1    Male  19.0    15.0                     NaN
# 1      2    Male   NaN    15.0                    81.0
# 2      3  Female  20.0    16.0                     6.0
# 3      4  Female  23.0     NaN                    77.0
# 4      5  Female   NaN     NaN                    40.0
# ..   ...     ...   ...     ...                     ...
# 195  196  Female  35.0   120.0                    79.0
# 196  197  Female  45.0   126.0                    28.0
# 197  198    Male  32.0   126.0                    74.0
# 198  199    Male  32.0   137.0                    18.0
# 199  200    Male  30.0   137.0                    83.0
#
# [200 rows x 5 columns]

# %% [markdown]
# c) Adding new columns:

# %%
#Creates a new column with all the values equal to 1
data_frame['NewColumn'] = 1
data_frame.head()
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0
#
#    NewColumn
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# ## **Apply Function**
#
# a) By defining a function beforehand
#
# The apply( ) function is used to iterate over a data frame. It can also be used with lambda functions.

# %%
# Apply function
def satisfaction(value):
    if value > 70:
        return "Satisfied"

    else:
        return "Unsatisfied"

data_frame['Customer Satisfaction'] = data_frame['Spending Score (1-100)'].apply(satisfaction)
data_frame.head(10)
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0
# 5           6  Female  22.0                17.0                    76.0
# 6           7  Female   NaN                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                     3.0
# 9          10  Female  30.0                19.0                    72.0
#
#    NewColumn Customer Satisfaction
# 0          1           Unsatisfied
# 1          1             Satisfied
# 2          1           Unsatisfied
# ...

# %% [markdown]
# ## **Visualizing DataFrame**
# a) Scatter plot
#
# The plot( ) function is used to make plots of the data frames.

# %%
# Visualization
data_frame.plot(x ='CustomerID', y='Spending Score (1-100)',kind = 'scatter')
# Out:
# <Axes: xlabel='CustomerID', ylabel='Spending Score (1-100)'>

# %% [markdown]
# b) Histogram
#
# The plot.hist( ) function is used to make plots of the data frames.

# %%
data_frame.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Plotting histogarm for one column
data_frame.hist(column='Age')
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
data_frame.hist(column='Spending Score (1-100)')
# Out:
# array([[<Axes: title={'center': 'Spending Score (1-100)'}>]], dtype=object)

# %% [markdown]
# ### **Saving your prepared Data as CSV file**
# You can use the following template in Python in order to export your Pandas DataFrame to a CSV file:
# data_frame.to_csv(r'Path where you want to store the exported CSV file\File Name.csv', index=False)

# %%
#This will save the dataset without the raws indeces
data_frame.to_csv(r'/content/Prepared_Mall_Customers.csv', index=False)

# %%
#This will save the dataset with the raws indeces
data_frame.to_csv(r'/content/Index_Prepared_Mall_Customers.csv')

# %% [markdown]
# # **Homework: More Methods working with Missing Data**
# Missing Data can occur when no information is provided for one or more items or for a whole unit. Missing Data is a very big problem in a real-life scenarios. Missing Data can also refer to as NA(Not Available) values in pandas. In DataFrame sometimes many datasets simply arrive with missing data, either because it exists and was not collected or it never existed. For Example, Suppose different users being surveyed may choose not to share their income, some users may choose not to share the address in this way many datasets went missing.
#
# Pandas treat None and NaN as essentially interchangeable for indicating missing or null values. To facilitate this convention, there are several useful functions for detecting, removing, and replacing null values in Pandas DataFrame :
#
#     isnull()
#     notnull()
#     dropna()
#     fillna()
#     replace()
#     interpolate()

# %% [markdown]
# Load the employees dataset

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/employees.csv")
data.shape
# Out:
# (1000, 8)

# %%
data
# Out:
#     First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0      Douglas    Male  08/06/1993        12:42 pm   97308.0    6.945
# 1       Thomas    Male   3/31/1996         6:53 am   61933.0    4.170
# 2        Maria  Female   4/23/1993        11:17 am  130590.0      NaN
# 3        Jerry    Male  03/04/2005         1:00 pm  138705.0      NaN
# 4        Larry    Male   1/24/1998         4:47 pm  101004.0      NaN
# ..         ...     ...         ...             ...       ...      ...
# 995      Henry     NaN  11/23/2014         6:09 am  132483.0   16.655
# 996    Phillip    Male   1/31/1984         6:30 am   42392.0   19.675
# 997    Russell    Male   5/20/2013        12:39 pm   96914.0    1.421
# 998      Larry    Male   4/20/2013         4:45 pm   60500.0   11.985
# 999     Albert    Male   5/15/2012         6:24 pm  129949.0   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
#To see the missingness in each column
data.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                13
# Bonus %               16
# Senior Management     67
# Team                  43
# dtype: int64

# %%
data[100:400]
# Out:
#     First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 100    Melissa  Female   6/21/2005         6:33 am       NaN   14.995
# 101      Aaron    Male   2/17/2012        10:20 am       NaN   11.849
# 102       Jack    Male  01/12/1997         5:51 am       NaN   12.159
# 103    Phyllis  Female  10/11/1996         9:30 pm  136984.0    8.932
# 104       John    Male  12/23/1989         7:01 am   80740.0   19.305
# ..         ...     ...         ...             ...       ...      ...
# 395      Kathy  Female  11/25/2001         9:55 pm   93753.0    7.094
# 396       Rose  Female  07/06/2002         3:57 pm   63494.0   19.385
# 397   Clarence    Male   1/13/2005         9:00 am  116693.0   13.835
# 398      Doris  Female   7/29/1992         6:40 pm   85215.0    7.425
# 399    Kathryn  Female  06/09/1988         9:29 am   86439.0    7.799
#
#     Senior Management             Team
# 100             False          Finance
# 101              True        Marketing
# ...

# %%
# creating bool series True for NaN values
bool_series = pd.isnull(data["Gender"])

# filtering data
# displaying data only with Gender = NaN
data[bool_series]
# Out:
#     First Name Gender  Start Date Last Login Time    Salary  Bonus %  \
# 20        Lois    NaN   4/22/1995         7:18 pm   64714.0    4.934
# 22      Joshua    NaN  03/08/2012         1:58 am   90816.0   18.816
# 27       Scott    NaN  07/11/1991         6:58 pm       NaN    5.218
# 31       Joyce    NaN   2/20/2005         2:40 pm   88657.0   12.752
# 41   Christine    NaN   6/28/2015         1:08 am   66582.0   11.308
# ..         ...    ...         ...             ...       ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 pm  103050.0    3.050
# 972     Victor    NaN   7/28/2006         2:49 pm   76381.0   11.159
# 985    Stephen    NaN  07/10/1983         8:10 pm   85668.0    1.909
# 989     Justin    NaN  02/10/1991         4:58 pm   38344.0    3.794
# 995      Henry    NaN  11/23/2014         6:09 am  132483.0   16.655
#
#     Senior Management                  Team
# 20               True                 Legal
# 22               True       Client Services
# ...

# %% [markdown]
# only the rows having Gender = NULL are displayed.

# %%
# creating bool series True for NaN values
bool_series = pd.notnull(data["Gender"])

# filtering data
# displaying data only with Gender = Not NaN
data[bool_series]
# Out:
#     First Name  Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0      Douglas    Male  08/06/1993        12:42 pm   97308.0    6.945
# 1       Thomas    Male   3/31/1996         6:53 am   61933.0    4.170
# 2        Maria  Female   4/23/1993        11:17 am  130590.0      NaN
# 3        Jerry    Male  03/04/2005         1:00 pm  138705.0      NaN
# 4        Larry    Male   1/24/1998         4:47 pm  101004.0      NaN
# ..         ...     ...         ...             ...       ...      ...
# 994     George    Male   6/21/2013         5:47 pm   98874.0    4.479
# 996    Phillip    Male   1/31/1984         6:30 am   42392.0   19.675
# 997    Russell    Male   5/20/2013        12:39 pm   96914.0    1.421
# 998      Larry    Male   4/20/2013         4:45 pm   60500.0   11.985
# 999     Albert    Male   5/15/2012         6:24 pm  129949.0   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %% [markdown]
# Output: As shown in the output image, only the rows having Gender = NOT NULL are displayed.

# %% [markdown]
# Now we are going to fill all the null values in Gender column with “No Gender”

# %%
# filling a null values using fillna()
data["Gender"].fillna("No Gender", inplace = True)

data
# Out:
#     First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0      Douglas       Male  08/06/1993        12:42 pm   97308.0    6.945
# 1       Thomas       Male   3/31/1996         6:53 am   61933.0    4.170
# 2        Maria     Female   4/23/1993        11:17 am  130590.0      NaN
# 3        Jerry       Male  03/04/2005         1:00 pm  138705.0      NaN
# 4        Larry       Male   1/24/1998         4:47 pm  101004.0      NaN
# ..         ...        ...         ...             ...       ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 am  132483.0   16.655
# 996    Phillip       Male   1/31/1984         6:30 am   42392.0   19.675
# 997    Russell       Male   5/20/2013        12:39 pm   96914.0    1.421
# 998      Larry       Male   4/20/2013         4:45 pm   60500.0   11.985
# 999     Albert       Male   5/15/2012         6:24 pm  129949.0   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %% [markdown]
# Filling null values with the previous ones

# %%
# filling a missing value with
# previous ones
data_pad=data.fillna(method ='pad')
data_pad
# Out:
#     First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0      Douglas       Male  08/06/1993        12:42 pm   97308.0    6.945
# 1       Thomas       Male   3/31/1996         6:53 am   61933.0    4.170
# 2        Maria     Female   4/23/1993        11:17 am  130590.0    4.170
# 3        Jerry       Male  03/04/2005         1:00 pm  138705.0    4.170
# 4        Larry       Male   1/24/1998         4:47 pm  101004.0    4.170
# ..         ...        ...         ...             ...       ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 am  132483.0   16.655
# 996    Phillip       Male   1/31/1984         6:30 am   42392.0   19.675
# 997    Russell       Male   5/20/2013        12:39 pm   96914.0    1.421
# 998      Larry       Male   4/20/2013         4:45 pm   60500.0   11.985
# 999     Albert       Male   5/15/2012         6:24 pm  129949.0   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# Filling null value with the next ones

# %%
# filling  null value using fillna() function
data_previous=data.fillna(method ='bfill')
data_previous
# Out:
#     First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 0      Douglas       Male  08/06/1993        12:42 pm   97308.0    6.945
# 1       Thomas       Male   3/31/1996         6:53 am   61933.0    4.170
# 2        Maria     Female   4/23/1993        11:17 am  130590.0   10.125
# 3        Jerry       Male  03/04/2005         1:00 pm  138705.0   10.125
# 4        Larry       Male   1/24/1998         4:47 pm  101004.0   10.125
# ..         ...        ...         ...             ...       ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 am  132483.0   16.655
# 996    Phillip       Male   1/31/1984         6:30 am   42392.0   19.675
# 997    Russell       Male   5/20/2013        12:39 pm   96914.0    1.421
# 998      Larry       Male   4/20/2013         4:45 pm   60500.0   11.985
# 999     Albert       Male   5/15/2012         6:24 pm  129949.0   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# Look at the data between the following records 23:33

# %%
# Printing the first 23 to 33 rows of
# the data frame for visualization
data[23:33]
# Out:
#    First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 23        NaN       Male   6/14/2012         4:19 pm  125792.0    5.042
# 24       John       Male  07/01/1992        10:08 pm   97950.0   13.873
# 25        NaN       Male  10/08/2012         1:12 am   37076.0   18.576
# 26      Craig       Male   2/27/2000         7:45 am       NaN    7.757
# 27      Scott  No Gender  07/11/1991         6:58 pm       NaN    5.218
# 28      Terry       Male  11/27/1981         6:30 pm       NaN   13.464
# 29   Benjamin       Male   1/26/2005        10:06 pm       NaN    7.008
# 30  Christina     Female  08/06/2002         1:19 pm  118780.0    9.096
# 31      Joyce  No Gender   2/20/2005         2:40 pm   88657.0   12.752
# 32        NaN       Male   8/21/1998         2:27 pm  122340.0    6.417
#
#    Senior Management             Team
# 23               NaN              NaN
# 24             False  Client Services
# 25               NaN  Client Services
# ...

# %% [markdown]
# Now we are going to replace the all Nan value in the data frame with 40 value.

# %%
# will replace  Nan value in dataframe with value 40
import numpy as np
replaced_data=data.replace(to_replace = np.nan, value = 40)
replaced_data[23:33]
# Out:
#    First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 23         40       Male   6/14/2012         4:19 pm  125792.0    5.042
# 24       John       Male  07/01/1992        10:08 pm   97950.0   13.873
# 25         40       Male  10/08/2012         1:12 am   37076.0   18.576
# 26      Craig       Male   2/27/2000         7:45 am      40.0    7.757
# 27      Scott  No Gender  07/11/1991         6:58 pm      40.0    5.218
# 28      Terry       Male  11/27/1981         6:30 pm      40.0   13.464
# 29   Benjamin       Male   1/26/2005        10:06 pm      40.0    7.008
# 30  Christina     Female  08/06/2002         1:19 pm  118780.0    9.096
# 31      Joyce  No Gender   2/20/2005         2:40 pm   88657.0   12.752
# 32         40       Male   8/21/1998         2:27 pm  122340.0    6.417
#
#    Senior Management             Team
# 23                40               40
# 24             False  Client Services
# 25                40  Client Services
# ...

# %% [markdown]
# Let’s interpolate the missing values using Linear method. Note that Linear method ignore the index and treat the values as equally spaced.
# The forward direction means going from one index to the next index record

# %%
# to interpolate the missing values
imputed_data=data.interpolate(method ='linear', limit_direction ='forward')
imputed_data[23:33]
# Out:
#    First Name     Gender  Start Date Last Login Time    Salary  Bonus %  \
# 23        NaN       Male   6/14/2012         4:19 pm  125792.0    5.042
# 24       John       Male  07/01/1992        10:08 pm   97950.0   13.873
# 25        NaN       Male  10/08/2012         1:12 am   37076.0   18.576
# 26      Craig       Male   2/27/2000         7:45 am   53416.8    7.757
# 27      Scott  No Gender  07/11/1991         6:58 pm   69757.6    5.218
# 28      Terry       Male  11/27/1981         6:30 pm   86098.4   13.464
# 29   Benjamin       Male   1/26/2005        10:06 pm  102439.2    7.008
# 30  Christina     Female  08/06/2002         1:19 pm  118780.0    9.096
# 31      Joyce  No Gender   2/20/2005         2:40 pm   88657.0   12.752
# 32        NaN       Male   8/21/1998         2:27 pm  122340.0    6.417
#
#    Senior Management             Team
# 23               NaN              NaN
# 24             False  Client Services
# 25               NaN  Client Services
# ...

# %% [markdown]
# # **Data Scaling and Normalization in Python**
# In this tutorial, we’ll study several data scaling and normalization techniques in Python using both sklearn and conventional programming and we’ll share lots of examples. Here are the data scaling techniques we’re going to learn in this tutorial:
#
#     Standard Scaling
#     Min/Max Scaling
#     Mean Scaling
#     Maximum Absolute Scaling
#     Median and Quantile Scaling

# %% [markdown]
# Importing the Dataset
#
# We’re going to use the “tips” dataset from the Seaborn library to show examples of different data scaling techniques in this tutorial.
#
# The “tips” dataset is a fictional dataset containing information related to meals ordered at a restaurant.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

tips_ds  = sns.load_dataset('tips')
tips_ds.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Data scaling is applied to numeric columns. In our “tips” dataset we have three numeric columns: total_bill, tip, size. The script below filters these three columns and removes the remaining columns.

# %%
tips_ds_numeric = tips_ds.filter(["total_bill", "tip", "size"], axis = 1)
tips_ds_numeric.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
# You can see from the above output that our dataset now contains just three columns. Notice the scale of data for the total_bill column is very different from the tip and size columns.
#
# Let’s plot some statistical values for the columns in our dataset using the describe() method.

# %%
tips_ds_numeric.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# The above output confirms our three columns are not scaled. The mean, minimum and maximum values, and even the standard deviation values for all three columns are very different.
#
# This unscaled dataset is not suitable for processing by some statistical algorithms. We need to scale this data so that’s exactly what we’ll do in the upcoming sections where we’ll show you different types of data scaling techniques in action.

# %% [markdown]
# # **Standard Scaling**
#
# Several machine learning algorithms, like linear regression support vector machines (SVMs) assume all the features in a dataset are centered around 0 and have unit variances. It’s a common practice to apply standard scaling to your data before training these machine learning algorithms on your dataset.
#
# In standard scaling, a feature is scaled by subtracting the mean from all the data points and dividing the resultant values by the standard deviation of the data.

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
tips_ds_scaled = ss.fit_transform(tips_ds_numeric)

# %%
# This is not pretty, it is called an array
tips_ds_scaled
# Out:
# array([[-3.14711305e-01, -1.43994695e+00, -6.00192629e-01],
#        [-1.06323531e+00, -9.69205340e-01,  4.53382921e-01],
#        [ 1.37779900e-01,  3.63355539e-01,  4.53382921e-01],
#        [ 4.38315103e-01,  2.25754144e-01, -6.00192629e-01],
#        [ 5.40744704e-01,  4.43019505e-01,  1.50695847e+00],
#        [ 6.19536705e-01,  1.23965916e+00,  1.50695847e+00],
#        [-1.23995452e+00, -7.22971264e-01, -6.00192629e-01],
#        [ 7.98507107e-01,  8.81527488e-02,  1.50695847e+00],
#        [-5.34203307e-01, -7.51939979e-01, -6.00192629e-01],
#        [-5.63468908e-01,  1.67816714e-01, -6.00192629e-01],
#        [-1.07111451e+00, -9.32994446e-01, -6.00192629e-01],
#        [ 1.74175992e+00,  1.44968234e+00,  1.50695847e+00],
#        [-4.91430507e-01, -1.03438495e+00, -6.00192629e-01],
#        [-1.52624903e-01,  1.24660453e-03,  1.50695847e+00],
#        [-5.57840908e-01,  1.57309619e-02, -6.00192629e-01],
#        [ 2.01939101e-01,  6.67527044e-01, -6.00192629e-01],
# ...

# %% [markdown]
# The fit_transform() method returns a NumPy array which you can convert to a Pandas Dataframe by passing the array to the Dataframe class constructor. The following script makes the conversion and prints the header for our newly scaled dataset.

# %%
tips_ds_scaled_df = pd.DataFrame(tips_ds_scaled,columns = tips_ds_numeric.columns)
tips_ds_scaled_df.head()
# Out:
#    total_bill       tip      size
# 0   -0.314711 -1.439947 -0.600193
# 1   -1.063235 -0.969205  0.453383
# 2    0.137780  0.363356  0.453383
# 3    0.438315  0.225754 -0.600193
# 4    0.540745  0.443020  1.506958

# %%
tips_ds_scaled_df.describe()
# Out:
#          total_bill           tip          size
# count  2.440000e+02  2.440000e+02  2.440000e+02
# mean  -7.871663e-17  2.839259e-16 -5.824121e-17
# std    1.002056e+00  1.002056e+00  1.002056e+00
# min   -1.881547e+00 -1.447189e+00 -1.653768e+00
# 25%   -7.247111e-01 -7.229713e-01 -6.001926e-01
# 50%   -2.241005e-01 -7.117518e-02 -6.001926e-01
# 75%    4.886857e-01  4.086192e-01  4.533829e-01
# max    3.492068e+00  5.070772e+00  3.614110e+00

# %% [markdown]
# # **Min/Max Scaling**
#
# Min/Max scaling normalizes the data between 0 and 1 by subtracting the overall minimum value from each data point and dividing the result by the difference between the minimum and maximum values.
#
# The Min/Max scaler is commonly used for data scaling when the maximum and minimum values for data points are known. For instance, you can use the min/max scaler to normalize image pixels having values between 0 and 255.
#
# You’ll want to use the MinMaxScaler class from the sklearn.preprocessing module to perform min/max scaling. The fit_transform method of the class performs the min/max scaling on the input Pandas Dataframe, as shown below:

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()
tips_ds_mms = mms.fit_transform(tips_ds_numeric)

# %%
# This is not pretty, it is called an array
tips_ds_mms
# Out:
# array([[0.29157939, 0.00111111, 0.2       ],
#        [0.1522832 , 0.07333333, 0.4       ],
#        [0.3757855 , 0.27777778, 0.4       ],
#        [0.43171345, 0.25666667, 0.2       ],
#        [0.45077503, 0.29      , 0.6       ],
#        [0.46543779, 0.41222222, 0.6       ],
#        [0.11939673, 0.11111111, 0.2       ],
#        [0.49874319, 0.23555556, 0.6       ],
#        [0.25073314, 0.10666667, 0.2       ],
#        [0.24528697, 0.24777778, 0.2       ],
#        [0.15081693, 0.07888889, 0.2       ],
#        [0.67427734, 0.44444444, 0.6       ],
#        [0.25869292, 0.06333333, 0.2       ],
#        [0.32174277, 0.22222222, 0.6       ],
#        [0.24633431, 0.22444444, 0.2       ],
#        [0.38772518, 0.32444444, 0.2       ],
#        [0.15207373, 0.07444444, 0.4       ],
#        [0.27691663, 0.30111111, 0.4       ],
#        [0.29116045, 0.27777778, 0.4       ],
#        [0.36824466, 0.26111111, 0.4       ],
#        [0.31105991, 0.34222222, 0.2       ],
# ...

# %%
tips_ds_mms_df = pd.DataFrame(tips_ds_mms,columns = tips_ds_numeric.columns)
tips_ds_mms_df.head()
# Out:
#    total_bill       tip  size
# 0    0.291579  0.001111   0.2
# 1    0.152283  0.073333   0.4
# 2    0.375786  0.277778   0.4
# 3    0.431713  0.256667   0.2
# 4    0.450775  0.290000   0.6

# %%
tips_ds_mms_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean     0.350145    0.222031    0.313934
# std      0.186477    0.153738    0.190220
# min      0.000000    0.000000    0.000000
# 25%      0.215281    0.111111    0.200000
# 50%      0.308442    0.211111    0.200000
# 75%      0.441087    0.284722    0.400000
# max      1.000000    1.000000    1.000000
